# %% [markdown]
# 1. Đọc file stock.csv

# %%
import csv
import pandas as pd
from datetime import datetime

# %%
path = 'C:/Users/Admin/Documents/lesson1 Data science/Nguyen_Manh_Cuong_23174600007_DHKL17A1HN/DHKL17A1HN/Lab03/Data/stocks1.csv'
stocks1 = []
with open(path,'r',encoding='utf-8') as file:
    read = csv.reader(file)

    header = next(read)

    data = list(read)

    for i,row in enumerate(data):
        for j,value in enumerate(row):
            if j==1:
                continue
            try:
                value_str = str(value).strip()
                if not value_str:
                    data[i][j] = None
                elif j==0:
                    continue
                
                elif '.' in value_str:
                    data[i][j] = float(value_str)
                else:
                    data[i][j] = int(value_str)
            except ValueError as e:
                print(f'Không chuyển đổi được giá trị "{value}" ở dòng {i+1}, cột {j+1}: {e}')

for i in data:
    stocks1.append(dict(zip(header,i)))
stocks1
# Out:
# [{'date': '01-03-19',
#   'symbol': 'AMZN',
#   'open': 1655.13,
#   'high': 1674.26,
#   'low': 1651,
#   'close': 1671.73,
#   'volume': 4974877},
#  {'date': '04-03-19',
#   'symbol': 'AMZN',
#   'open': 1685,
#   'high': 1709.43,
#   'low': 1674.36,
#   'close': 1696.17,
#   'volume': 6167358},
#  {'date': '05-03-19',
#   'symbol': 'AMZN',
#   'open': 1702.95,
#   'high': 1707.8,
#   'low': 1689.01,
#   'close': 1692.43,
#   'volume': 3681522},
#  {'date': '06-03-19',
#   'symbol': 'AMZN',
#   'open': 1695.97,
#   'high': None,
#   'low': None,
#   'close': 1668.95,
#   'volume': 3996001},
#  {'date': '07-03-19',
#   'symbol': 'AMZN',
#   'open': 1667.37,
#   'high': 1669.75,
#   'low': 1620.51,
#   'close': 1625.95,
#   'volume': 4957017},
#  {'date': '01-03-19',
#   'symbol': 'AAPL',
#   'open': 174.28,
#   'high': 175.15,
#   'low': 172.89,
#   'close': 174.97,
#   'volume': 25886167},
#  {'date': '04-03-19',
#   'symbol': 'AAPL',
#   'open': 175.69,
#   'high': 177.75,
# ...

# %%
pd_stocks1 = pd.DataFrame(stocks1)
pd_stocks1
# Out:
#         date symbol     open     high      low    close    volume
# 0   01-03-19   AMZN  1655.13  1674.26  1651.00  1671.73   4974877
# 1   04-03-19   AMZN  1685.00  1709.43  1674.36  1696.17   6167358
# 2   05-03-19   AMZN  1702.95  1707.80  1689.01  1692.43   3681522
# 3   06-03-19   AMZN  1695.97      NaN      NaN  1668.95   3996001
# 4   07-03-19   AMZN  1667.37  1669.75  1620.51  1625.95   4957017
# 5   01-03-19   AAPL   174.28   175.15   172.89   174.97  25886167
# 6   04-03-19   AAPL   175.69   177.75   173.97   175.85  27436203
# 7   05-03-19   AAPL   175.94   176.00   174.54   175.53  19737419
# 8   06-03-19   AAPL   174.67   175.49   173.94   174.52  20810384
# 9   07-03-19   AAPL   173.87   174.44   172.02   172.50  24796374
# 10  01-03-19   GOOG  1124.90  1142.97  1124.75  1140.99   1450316
# 11  04-03-19   GOOG  1146.99  1158.28  1130.69  1147.80   1446047
# 12  05-03-19   GOOG  1150.06      NaN      NaN  1162.03   1443174
# ...

# %% [markdown]
# 2. Hiển thị 5 dòng đầu tiên của pd

# %%
pd_stocks1[0:5]
# Out:
#        date symbol     open     high      low    close   volume
# 0  01-03-19   AMZN  1655.13  1674.26  1651.00  1671.73  4974877
# 1  04-03-19   AMZN  1685.00  1709.43  1674.36  1696.17  6167358
# 2  05-03-19   AMZN  1702.95  1707.80  1689.01  1692.43  3681522
# 3  06-03-19   AMZN  1695.97      NaN      NaN  1668.95  3996001
# 4  07-03-19   AMZN  1667.37  1669.75  1620.51  1625.95  4957017

# %% [markdown]
# 3.Hiển thị kiểu dữ liệu (dtype) của mỗi cột

# %%
print(pd_stocks1.dtypes)
# Out:
# date       object
# symbol     object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# dtype: object

# %% [markdown]
# 4.Xem thông tin tổng quan của stocks1

# %%
pd_stocks1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    15 non-null     object
#  1   symbol  15 non-null     object
#  2   open    15 non-null     float64
#  3   high    13 non-null     float64
#  4   low     13 non-null     float64
#  5   close   15 non-null     float64
#  6   volume  15 non-null     int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 968.0+ bytes

# %%
pd_stocks1.describe()
# Out:
#               open         high          low        close        volume
# count    15.000000    13.000000    13.000000    15.000000  1.500000e+01
# mean   1001.402000   943.511538   926.775385   998.705333  9.936580e+06
# std     645.683362   668.389987   655.705275   642.198730  1.036832e+07
# min     173.870000   174.440000   172.020000   172.500000  1.099289e+06
# 25%     175.815000   176.000000   173.970000   175.690000  1.448182e+06
# 50%    1150.060000  1156.760000  1130.690000  1147.800000  4.957017e+06
# 75%    1661.250000  1669.750000  1620.510000  1647.450000  2.027390e+07
# max    1702.950000  1709.430000  1689.010000  1696.170000  2.743620e+07
