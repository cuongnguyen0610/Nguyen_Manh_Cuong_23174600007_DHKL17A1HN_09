# %% [markdown]
# Lab3.4 Kết hợp dữ liệu từ nhiều nguồn

# %% [markdown]
# 1. Đọc file company.csv và đưa nó vào Data Frame

# %%
import pandas as pd
import csv

# %%
path = 'C:/Users/Admin/Documents/lesson1 Data science/Nguyen_Manh_Cuong_23174600007_DHKL17A1HN/DHKL17A1HN/Lab03/Data/stocks1.csv'
path1 = 'C:/Users/Admin/Documents/lesson1 Data science/Nguyen_Manh_Cuong_23174600007_DHKL17A1HN/DHKL17A1HN/Lab03/Data/stocks2.csv'
pd_stocks1 = pd.read_csv(path)
pd_stocks2 = pd.read_csv(path1)

# %%
pd_stocks1.fillna(pd_stocks1['high'].mean(),inplace=True)
pd_stocks1
# Out:
#         date symbol     open         high          low    close    volume
# 0   01-03-19   AMZN  1655.13  1674.260000  1651.000000  1671.73   4974877
# 1   04-03-19   AMZN  1685.00  1709.430000  1674.360000  1696.17   6167358
# 2   05-03-19   AMZN  1702.95  1707.800000  1689.010000  1692.43   3681522
# 3   06-03-19   AMZN  1695.97   943.511538   943.511538  1668.95   3996001
# 4   07-03-19   AMZN  1667.37  1669.750000  1620.510000  1625.95   4957017
# 5   01-03-19   AAPL   174.28   175.150000   172.890000   174.97  25886167
# 6   04-03-19   AAPL   175.69   177.750000   173.970000   175.85  27436203
# 7   05-03-19   AAPL   175.94   176.000000   174.540000   175.53  19737419
# 8   06-03-19   AAPL   174.67   175.490000   173.940000   174.52  20810384
# 9   07-03-19   AAPL   173.87   174.440000   172.020000   172.50  24796374
# 10  01-03-19   GOOG  1124.90  1142.970000  1124.750000  1140.99   1450316
# 11  04-03-19   GOOG  1146.99  1158.280000  1130.690000  1147.80   1446047
# ...

# %%
stocks = pd.concat((pd_stocks1,pd_stocks2),ignore_index=True)
stocks
# Out:
#         date symbol     open         high          low    close    volume
# 0   01-03-19   AMZN  1655.13  1674.260000  1651.000000  1671.73   4974877
# 1   04-03-19   AMZN  1685.00  1709.430000  1674.360000  1696.17   6167358
# 2   05-03-19   AMZN  1702.95  1707.800000  1689.010000  1692.43   3681522
# 3   06-03-19   AMZN  1695.97   943.511538   943.511538  1668.95   3996001
# 4   07-03-19   AMZN  1667.37  1669.750000  1620.510000  1625.95   4957017
# 5   01-03-19   AAPL   174.28   175.150000   172.890000   174.97  25886167
# 6   04-03-19   AAPL   175.69   177.750000   173.970000   175.85  27436203
# 7   05-03-19   AAPL   175.94   176.000000   174.540000   175.53  19737419
# 8   06-03-19   AAPL   174.67   175.490000   173.940000   174.52  20810384
# 9   07-03-19   AAPL   173.87   174.440000   172.020000   172.50  24796374
# 10  01-03-19   GOOG  1124.90  1142.970000  1124.750000  1140.99   1450316
# 11  04-03-19   GOOG  1146.99  1158.280000  1130.690000  1147.80   1446047
# ...

# %%
path = 'C:/Users/Admin/Documents/lesson1 Data science/Nguyen_Manh_Cuong_23174600007_DHKL17A1HN/DHKL17A1HN/Lab03/Data/companies.csv'
companies = pd.read_csv(path)
companies
# Out:
#    name  employees headquarters_city headquarters_state
# 0  AMZN     613300           Seattle                 WA
# 1  GOOG      98771     Mountain View                 CA
# 2  AAPL     132000         Cupertino                 CA
# 3    FB      48268        Menlo Park                 CA
# 4  TSLA      48016         Palo Alto                 CA

# %%
merge_value = pd.merge(stocks, companies, left_on='symbol', right_on='name', how='left')
merge_value
# Out:
#         date symbol     open         high          low    close    volume  \
# 0   01-03-19   AMZN  1655.13  1674.260000  1651.000000  1671.73   4974877
# 1   04-03-19   AMZN  1685.00  1709.430000  1674.360000  1696.17   6167358
# 2   05-03-19   AMZN  1702.95  1707.800000  1689.010000  1692.43   3681522
# 3   06-03-19   AMZN  1695.97   943.511538   943.511538  1668.95   3996001
# 4   07-03-19   AMZN  1667.37  1669.750000  1620.510000  1625.95   4957017
# 5   01-03-19   AAPL   174.28   175.150000   172.890000   174.97  25886167
# 6   04-03-19   AAPL   175.69   177.750000   173.970000   175.85  27436203
# 7   05-03-19   AAPL   175.94   176.000000   174.540000   175.53  19737419
# 8   06-03-19   AAPL   174.67   175.490000   173.940000   174.52  20810384
# 9   07-03-19   AAPL   173.87   174.440000   172.020000   172.50  24796374
# 10  01-03-19   GOOG  1124.90  1142.970000  1124.750000  1140.99   1450316
# 11  04-03-19   GOOG  1146.99  1158.280000  1130.690000  1147.80   1446047
# ...

# %% [markdown]
# 3. Tính giá đóng cửa trung bình của mỗi công ty (close)

# %%
avg_value = merge_value.groupby('headquarters_city')['close'].mean()
avg_value
# Out:
# headquarters_city
# Cupertino         174.674
# Menlo Park        168.510
# Mountain View    1150.396
# Palo Alto         281.904
# Seattle          1671.046
# Name: close, dtype: float64

# %% [markdown]
# 4.Hiển thị kết quả cho 5 ngày đầu tiên

# %%
merge_value[0:5]
# Out:
#        date symbol     open         high          low    close   volume  name  \
# 0  01-03-19   AMZN  1655.13  1674.260000  1651.000000  1671.73  4974877  AMZN
# 1  04-03-19   AMZN  1685.00  1709.430000  1674.360000  1696.17  6167358  AMZN
# 2  05-03-19   AMZN  1702.95  1707.800000  1689.010000  1692.43  3681522  AMZN
# 3  06-03-19   AMZN  1695.97   943.511538   943.511538  1668.95  3996001  AMZN
# 4  07-03-19   AMZN  1667.37  1669.750000  1620.510000  1625.95  4957017  AMZN
#
#    employees headquarters_city headquarters_state
# 0     613300           Seattle                 WA
# 1     613300           Seattle                 WA
# 2     613300           Seattle                 WA
# 3     613300           Seattle                 WA
# 4     613300           Seattle                 WA
